# %% [markdown]
# # Restricted Boltzmann Machine

# %%
import numpy as np
import matplotlib.pyplot as plt
from rbm import RBM

# %% [markdown]
# ## Load Mnist

# %%
import mnist
train_imgs = mnist.train_images()

# %% [markdown]
# ## Plot Mnist data

# %%
def show_mnist(X, title = None, loc = 'center',**kwargs):
    num = X.shape[0]
    if num <= 10:
        imgs = np.moveaxis(X.reshape(-1, num, 28, 28), 1, 2).reshape(-1, num * 28)
        plt.figure(figsize=(num/2,num))
        if title:
            plt.title(title, kwargs, loc=loc)
        plt.axis('off')
        plt.imshow(imgs)
    elif num <= 100 and num % 10 == 0:
        imgs = np.moveaxis(X.reshape(-1, 10, 28, 28), 1, 2).reshape(-1, 10 * 28)
        plt.figure(figsize=(10,20))
        if title:
            plt.title(title, kwargs, loc=loc)
        plt.axis('off')
        plt.imshow(imgs,cmap=)
    elif num <= 200 and num % 20 == 0:
        imgs = np.moveaxis(X.reshape(-1, 20, 28, 28), 1, 2).reshape(-1, 20 * 28)
        plt.figure(figsize=(10,20))
        if title:
            plt.title(title, kwargs, loc=loc)
        plt.axis('off')
        plt.imshow(imgs)
    else:
        print(f'{num} not fit, choose from:')
        print(list(range(1,10)))
        print([x for x in range(10,100,10)])
        print([x for x in range(100,1000,100)])

# %%
level:idxs = np.random.randint(0, len(train_imgs), 200) 
show_mnist(train_imgs[idxs],'Mnist:',loc = 'left', fontsize = 'xx-large')

# %% [markdown]
# ## Initial RBM

# %%
mini_x = train_imgs[:10000]
mini_x = mini_x.reshape(-1,784)
Train data : Contrastive Divergence
In [18]:
￼
model.cd(mini_binary,10000)
Epoch 0: Error is 9814.465872683037
Epoch 100: Error is 2187.3519768438064
Epoch 200: Error is 1921.252723344945
Epoch 300: Error is 2064.70951098031
Epoch 400: Error is 1673.399674304583
Epoch 500: Error is 1686.6127519098
Epoch 600: Error is 1888.5158897631652
Epoch 700: Error is 1696.4099013389339
Epoch 800: Error is 1577.932839872817
Epoch 900: Error is 1485.6138011701091
Epoch 1000: Error is 1529.7615843063923
Epoch 1100: Error is 1582.0256558933902
Epoch 1200: Error is 1711.0468936566078
Epoch 1300: Error is 1583.5841397295028
Epoch 1400: Error is 1583.7093071858824
Epoch 1500: Error is 1665.9268817742752
Epoch 1600: Error is 1595.5581476913476
Epoch 1700: Error is 1634.696593216856
Epoch 1800: Error is 1455.2004251993471
Epoch 1900: Error is 1626.5969666725646
Epoch 2000: Error is 1579.8680325747146
Epoch 2100: Error is 1539.4721404749546
Epoch 2200: Error is 1453.7797194971786
Epoch 2300: Error is 1406.7204373874551
Epoch 2400: Error is 1337.7355587515076
Epoch 2500: Error is 1392.259688075709
Epoch 2600: Error is 1573.8853774979343
Epoch 2700: Error is 1422.2842351073114
Epoch 2800: Error is 1741.0426593620607
Epoch 2900: Error is 1483.7566176046687
Epoch 3000: Error is 1584.930805397195
Epoch 3100: Error is 1515.7583818124924
Epoch 3200: Error is 1495.922079890715
Epoch 3300: Error is 1534.6426768218291
Epoch 3400: Error is 1583.4113275184568
Epoch 3500: Error is 1439.014148098412
Epoch 3600: Error is 1551.9426424818762
Epoch 3700: Error is 1586.772819590416
Epoch 3800: Error is 1464.5938753807172
Epoch 3900: Error is 1494.466357397127
Epoch 4000: Error is 1552.6745731189478
Epoch 4100: Error is 1600.8463928750377
Epoch 4200: Error is 1437.6741551362215
Epoch 4300: Error is 1502.532688544746
Epoch 4400: Error is 1484.1259743700061
Epoch 4500: Error is 1402.8293590542264
Epoch 4600: Error is 1527.6215209856134
Epoch 4700: Error is 1393.9891306662703
Epoch 4800: Error is 1510.4620068502197
Epoch 4900: Error is 1548.0890865961958
Epoch 5000: Error is 1480.3039990531533
Epoch 5100: Error is 1315.383086924078
Epoch 5200: Error is 1479.6629611284118
Epoch 5300: Error is 1336.5890338479303
Epoch 5400: Error is 1497.7756591963243
Epoch 5500: Error is 1318.3171029193788
Epoch 5600: Error is 1531.9998004675206
Epoch 5700: Error is 1307.9039582402265
Epoch 5800: Error is 1473.4361484797812
Epoch 5900: Error is 1544.7675991380831
Epoch 6000: Error is 1506.379683736242
Epoch 6100: Error is 1371.686923279009
Epoch 6200: Error is 1370.841809641523
Epoch 6300: Error is 1263.7544283543548
Epoch 6400: Error is 1458.5409153981955
Epoch 6500: Error is 1560.5652048981858
Epoch 6600: Error is 1481.7826976036367
Epoch 6700: Error is 1519.5637833659014
Epoch 6800: Error is 1349.3207952741436
Epoch 6900: Error is 1762.1184393485892
Epoch 7000: Error is 1455.7178150691868
Epoch 7100: Error is 1579.646234343912
Epoch 7200: Error is 1521.652059442792
Epoch 7300: Error is 1472.214826193786
Epoch 7400: Error is 1354.6795388782314
Epoch 7500: Error is 1559.526866574664
Epoch 7600: Error is 1249.551556050405
Epoch 7700: Error is 1499.2139974121242
Epoch 7800: Error is 1357.4992801453564
Epoch 7900: Error is 1315.7959446359964
Epoch 8000: Error is 1366.2634970208187
Epoch 8100: Error is 1331.537877752444
Epoch 8200: Error is 1331.5011724117037
Epoch 8300: Error is 1513.5829675803207
Epoch 8400: Error is 1602.65
mini_binary = mini_x>0
model = RBM(num_visible = 784, num_hidden = 100)

# %% [markdown]
# ## Train data : Contrastive Divergence

# %%
model.cd(mini_binary,10000)
# Out:
# Epoch 0: Error is 9814.465872683037
# Epoch 100: Error is 2187.3519768438064
# Epoch 200: Error is 1921.252723344945
# Epoch 300: Error is 2064.70951098031
# Epoch 400: Error is 1673.399674304583
# Epoch 500: Error is 1686.6127519098
# Epoch 600: Error is 1888.5158897631652
# Epoch 700: Error is 1696.4099013389339
# Epoch 800: Error is 1577.932839872817
# Epoch 900: Error is 1485.6138011701091
# Epoch 1000: Error is 1529.7615843063923
# Epoch 1100: Error is 1582.0256558933902
# Epoch 1200: Error is 1711.0468936566078
# Epoch 1300: Error is 1583.5841397295028
# Epoch 1400: Error is 1583.7093071858824
# Epoch 1500: Error is 1665.9268817742752
# Epoch 1600: Error is 1595.5581476913476
# Epoch 1700: Error is 1634.696593216856
# Epoch 1800: Error is 1455.2004251993471
# Epoch 1900: Error is 1626.5969666725646
# Epoch 2000: Error is 1579.8680325747146
# Epoch 2100: Error is 1539.4721404749546
# Epoch 2200: Error is 1453.7797194971786
# Epoch 2300: Error is 1406.7204373874551
# ...

# %% [markdown]
# ## Reconstruct data

# %%
idxs = np.random.choice(5000, 20)
row = mini_x[idxs].reshape(20,-1)
row_binary = mini_binary[idxs].reshape(20,-1)
reconstruct,units = model.reconstruct(row, 10)
show_mnist(row,'Row:', loc= 'left', fontsize = 'xx-large')
show_mnist(row_binary,'Row binary:', loc= 'left', fontsize = 'xx-large')
show_mnist(reconstruct,'Reconstruct probability:',loc = 'left', fontsize = 'xx-large')
show_mnist(units,'Reconstruct binary units:',loc = 'left', fontsize = 'xx-large')

# %% [markdown]
# ## Reconstruct with 1 - value

# %%
row = np.ones((1,28*28))
reconstruct,units = model.reconstruct(row)
show_mnist(row,'Row:', loc= 'left', fontsize = 'xx-large')
show_mnist(reconstruct,'Reconstruct:',loc = 'left', fontsize = 'xx-large')
show_mnist(units,'Reconstruct binary units:',loc = 'left', fontsize = 'xx-large')

# %% [markdown]
# ## Visulize the Weights

# %%
weights = model.weights.T
show_mnist(weights,'Weights:',loc = 'left', fontsize = 'xx-large')
